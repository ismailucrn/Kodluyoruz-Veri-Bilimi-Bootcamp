# %% [markdown]
# <a id="4"></a>
# ## Level of Measurements (Ölçülme Ölçeği)
# * Levels of Measurements 4 tanedir: nominal, ordinal, interval ve ratio
# * Nominal
#     * Kategori vardır.
#     * Sıralanamazlar.
#     * Mesela Asya ülkeleri: Çin Hindistan gibi
#     * Yada kadın/erkek gibi
# * Ordinal:
#     * Sıralanabilir ama aralarındaki ilişki sayısal olarak anlamsızdır.
#     * Mesela bir anket düşünün şıklar "asla, bazen, genelde, her zaman" olsun. Genelde bazenden daha genel bir ifade ama sayısal olarak ne kadar dediğimiz zaman bu sorunun cevabı yok. Bu tarz verilere ordinal veri denir.
# * Nominal ve ordinal arasında sıralanabilirlik açısından fark var.
# * Interval:
#     * Belirli bir ölçeği vardır.
#     * Natural zero starting point yoktur. Mesela sıcaklık için sıfırdan başlıyor yada 10 dereceden başlıyor diyemeyiz.
#     * Mesela oda sıcaklığı 20 derece 10 dereceden sıcaktır gibi karşılaştırmalarda bulunabiliriz.
# * Ratio:
#     * True zero point vardır. Mesela yaş kilo gibi
#     * Belirli bir ölçeği vardır.
# * Bazı bilim insanları interval ve ratio tiplerini tek bir tip olarak kabul eder.

# %% [markdown]
# ![Time](meas_level.jpg)

# %% [markdown]
# <a id="6"></a>
# ## Population vs Sample
# * Population
#     * Bir gruptaki tüm üyeler
#     * Mesela bir ülkedeki tüm şehirler
# * Sample
#     * Bir grubun Subset'i yani alt kümesi
#     * Mesela bir ülkedeki X bölgesindeki bazı şehirler gibi
#
# ![Time](pop_vs_sample.jpg)

# %% [markdown]
# <a id="7"></a>
# ## Central Tendency (Merkezi Eğilim)
# * Mean: ortalama
# * Median: bir listede ortada ki sayı
# * Mode: bir listede en çok bulunan sayı
# * Mean vs Median:
#     * Mean outlier'lardan etkilenebilir bu nedenle mediam önemli. Mesela bir şirkette zam yapılmak istenirse neye bakmalı çalışanların maaş ortalaması yada maaş medyanı?

# %%
#********************************
import matplotlib.pyplot as plt
plt.style.use("ggplot")
import warnings
warnings.filterwarnings("ignore")
#********************************
import numpy as np
from scipy import stats
from statistics import mean, stdev
from math import sqrt

yas = [1,2,3,5,6,7,7,10,12,13]
# Mean
mean_yas = np.mean(yas)
print(mean_yas)
# Median
median_yas = np.median(yas)
print(median_yas)
# Mode
mode_yas = stats.mode(yas)
print(mode_yas)
# Out:
# 6.6
# 6.5
# ModeResult(mode=array([7]), count=array([2]))

# %%
salary = [1,4,3,2,5,4,2,3,1,500]
print("Mean of salary: ",np.mean(salary))
print("Mean of salary: ",np.median(salary))
# Out:
# Mean of salary:  52.5
# Mean of salary:  3.0

# %% [markdown]
# <a id="9"></a>
# ## Dispersion (Dağılım)
# * Dispersion dağılım demek. (spread out)
# * Range: Bir listede en büyük ve en küçük sayı arasında ki fark
# * Variance:
#     * varyans-değişiklik. Listedeki tüm noktalar ortalamadan ne kadar uzaklıkta
#     * ![Time](variance.jpg)
#     * Bazı formüllerde N yerine (N-1) olabilir. Bu sample variance(N-1) ve population variance(N) diye iki farklı kavram olmasından kaynaklanıyor ama şuan için çok önemli değil.
# * Standard deviation (std):
#     * Variance'ın kare kökü
#     * İlerde göreceğimiz dağılımlarda bir dağılımın içindeki değerlerin ortalamaya olan uzaklıklarının ne kadar olduğunu belirtmek için kullanacağımız bir kavram. Aslında çok kullanılan ve önemli bir kavram.
#     * ![Time](var_vs_std.jpg)
#
#     Standart sapma ve varyans arasındaki fark, aşağıdaki nedenlerle açıkça çizilebilir:
#
#     * Varyans, gözlemlerin aritmetik ortalamasından değişkenliği tanımlayan sayısal bir değerdir. Standart sapma, bir veri setinde gözlemlerin dağılımının bir ölçüsüdür.
#     * Varyans, ortalama kare sapmalardan başka bir şey değildir. Diğer yandan standart sapma, kök ortalama kare sapmadır.
#     * Varyans sigma karesi (σ2) ile gösterilirken standart sapma sigma (σ) olarak etiketlenir.
#     * Varyans, verilen veri setindeki değerlerden genellikle daha büyük olan kare birimlerle ifade edilir. Veri setindeki değerlerle aynı birimlerle ifade edilen standart sapmadır.
#     * Varyans, bir gruptaki bireylerin ne kadar yayıldığını ölçer. Tersine, Standart Sapma, bir veri kümesinin gözlemlerinin ortalamadan ne kadar farklı olduğunu ölçer.

# %%
# range
yas = [1,2,3,5,6,7,7,10,12,13]
print("Range: ", (np.max(yas)-np.min(yas)))

# variance
print("Variance: ", (np.var(yas)))
var = sum((yas - np.mean(yas))**2)/len(yas)
print("Variance with formula: ",var)

# std
print("Std: ", (np.std(yas)))
std = np.sqrt(sum((yas - np.mean(yas))**2)/len(yas))
print("Std with formula: ",std)
# Out:
# Range:  12
# Variance:  15.040000000000001
# Variance with formula:  15.040000000000001
# Std:  3.8781438859330635
# Std with formula:  3.8781438859330635

# %%
import matplotlib.pyplot as plt
y = np.random.uniform(5,8,100)
x1 = np.random.uniform(10,20,100)
x2 = np.random.uniform(0,30,100)

plt.scatter(x1,y,color="black")
plt.scatter(x2,y,color="orange")
plt.xlim([-1,31])
plt.ylim([2,11])
plt.xlabel("x")
plt.ylabel("y")
print("X1 mean: {} and meadian: {}".format(np.mean(x1),np.median(x1)))
print("X2 mean: {} and meadian: {}".format(np.mean(x2),np.median(x2)))
print(x1.std())
print(x2.std())
# Out:
# X1 mean: 14.553920092900917 and meadian: 14.400520611980712
# X2 mean: 14.842399398865197 and meadian: 14.652163845802395
# 2.755595955791011
# 8.406231421119454

# %%
x1
# Out:
# array([17.89778791, 18.3243015 , 12.32295683, 12.64737133, 12.85814892,
#        12.46995608, 12.62391935, 18.51279738, 17.69597212, 15.00996123,
#        11.43207056, 12.92378463, 11.91077216, 19.5392883 , 15.53366138,
#        10.23692435, 11.74338762, 15.15808418, 12.87191823, 16.46095783,
#        18.94579362, 10.72084542, 10.66548697, 12.77953621, 11.67676694,
#        13.38703664, 12.97421452, 12.98228449, 18.32869001, 15.46703524,
#        12.27841908, 17.39668766, 15.14339574, 12.06921246, 13.34093859,
#        18.52875373, 10.62319203, 13.90181341, 14.84482589, 19.84178378,
#        14.65607407, 16.92545968, 10.96058027, 15.38923777, 19.73974086,
#        12.05892951, 11.70063213, 14.70414136, 13.60399167, 17.31810043,
#        13.36673002, 12.16417409, 11.77356611, 17.83443675, 13.53383981,
#        16.94949189, 10.84233643, 11.01591186, 15.47190773, 15.9784482 ,
#        19.92448774, 17.78675018, 14.31155516, 15.32104989, 15.4090032 ,
# ...

# %%
x2
# Out:
# array([ 1.91103262, 17.24193732,  5.08128983, 19.86098198,  2.51894651,
#        26.74874995, 13.02865752, 26.55944097, 27.12778936,  9.04486914,
#        18.81239405, 23.034966  ,  6.58060903,  6.78050581, 13.56525607,
#        24.36945717,  1.70621059, 25.87815793, 19.50042953, 25.31610319,
#        23.59919646, 12.89234526,  4.0959209 , 25.75111926, 15.99309984,
#        16.94765479, 29.018889  ,  4.88557453,  0.12075126, 26.63894653,
#        25.96846325,  5.46968089, 26.71877501,  9.86359196, 25.88041463,
#         3.20806468, 17.21783774, 17.6199627 ,  7.38733063, 17.18072463,
#         7.47391452,  7.44817117, 19.42187362, 14.11931666, 13.4919379 ,
#        19.43118619, 13.3246726 ,  1.57925687, 17.73691518, 22.81693175,
#        17.33172826, 12.60401529, 21.62259944, 12.80293823, 16.17224085,
#         7.50868139,  7.40973229, 13.73490739, 17.7166086 , 21.8762835 ,
#        17.2985042 , 17.90521359,  2.56874175,  3.05147351, 14.94536795,
# ...

# %%
print(x1.mean())
print(x2.mean())
print(np.median(x1))
print(np.median(x2))
# Out:
# 14.553920092900917
# 14.842399398865197
# 14.400520611980712
# 14.652163845802395

# %%
plt.scatter(x1,y,color="black")
plt.scatter(x2,y,color="orange")
plt.xlim([-1,31])
plt.ylim([2,11])
plt.xlabel("x")
plt.ylabel("y")
print("X1 mean: {} and meadian: {}".format(np.mean(x1),np.median(x1)))
print("X2 mean: {} and meadian: {}".format(np.mean(x2),np.median(x2)))
print(x1.std())
print(x2.std())
# Out:
# X1 mean: 14.553920092900917 and meadian: 14.400520611980712
# X2 mean: 14.842399398865197 and meadian: 14.652163845802395
# 2.755595955791011
# 8.406231421119454

# %% [markdown]
# <a id="11"></a>
# ## Quartiles
# * Quartiles nedir?
#     * 1,4,5,6,8,9,11,12,13,14,15,16,17
#     * Medyan (ya da ortanca ya da Q2) bir anakütle ya da örneklem veri serisini küçükten büyüğe doğru sıraladığımızda, seriyi ortadan ikiye ayıran değere denir.
#     * Q1, bir anakütle ya da örneklem veri serisini küçükten büyüğe doğru sıraladığımızda, medyan ile en küçük değeri ortadan ikiye ayıran değere denir.
#     * Q3, bir anakütle ya da örneklem veri serisini küçükten büyüğe doğru sıraladığımızda, medyan ile en büyük değeri ortadan ikiye ayıran değere denir.
# * IQR(inter quartile range) = Q3-Q1
# * Outliers: Q1 - 1.5*IQR and Q3 + 1.5*IQR sınırları dışarısında kalan değerler
#     * ![Time](IQR.jpg)

# %%
# libraries
import pandas as pd
import seaborn as sns
plt.style.use("ggplot")
import warnings
warnings.filterwarnings("ignore")
# read data as pandas data frame
data = pd.read_csv("data.csv")
data = data.drop(['Unnamed: 32','id'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Latte\Desktop\Week_2\scripts\Statistical Learning_Hafta2.ipynb Cell 15 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/Week_2/scripts/Statistical%20Learning_Hafta2.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> warnings.filterwarnings("ignore")
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/Week_2/scripts/Statistical%20Learning_Hafta2.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a> # read data as pandas data frame
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/Week_2/scripts/Statistical%20Learning_Hafta2.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> data = pd.read_csv("data.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/Week_2/scripts/Statistical%20Learning_Hafta2.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> data = data.drop(['Unnamed: 32','id'],axis = 1)
#
# ...

# %%
#M ve B diagnosis için radius_mean'lerin IQR metoduyla outlierlarını buluyoruz.
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data_bening = data[data.diagnosis == "B"]
desc = data_bening.radius_mean.describe()
Q1 = desc[4]
Q3 = desc[6]
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
lower = data_bening[data_bening.radius_mean < lower_bound]
upper = data_bening[data_bening.radius_mean > upper_bound]
outlier_count = len(lower.radius_mean) + len(upper.radius_mean)
outlier_count
# Out:
# 3

# %%
print(lower_bound)
print(upper_bound)
# Out:
# 7.645000000000001
# 16.805

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
melted_data = pd.melt(data,id_vars = "diagnosis",value_vars = ["radius_mean"])
melted_data
# Out:
#     diagnosis     variable  value
# 0           M  radius_mean  17.99
# 1           M  radius_mean  20.57
# 2           M  radius_mean  19.69
# 3           M  radius_mean  11.42
# 4           M  radius_mean  20.29
# ..        ...          ...    ...
# 564         M  radius_mean  21.56
# 565         M  radius_mean  20.13
# 566         M  radius_mean  16.60
# 567         M  radius_mean  20.60
# 568         B  radius_mean   7.76
#
# [569 rows x 3 columns]

# %%
sns.boxplot(x="variable", y="value",hue="diagnosis",data=melted_data)
plt.show()

# %% [markdown]
# <a id="13"></a>
# ## Bivariate Data and Covariance (İki Değişkenli Veri ve Kovaryans)
# * Bivariate
#     * İki variable'ı karşılaştırır ve correlation var mı yok mu ona bakar.
#     * x ekseni independent variable
#     * y ekseni dependent variable. Dependent çünkü x e bağlı.
# * Correlation:
#     * İki variable arasındaki ilişkidir ancak nedensellik göstermez.
#     * İki variable birbiri ile correlated olabilir ama bu demek değildir ki birinin nedeni diğeridir.

# %%
data.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(data.corr(),ax=ax,annot= True,linewidths=0.5,fmt = ".1f")
plt.show()

# %%
# plt.figure(figsize = (15,10))
sns.jointplot(data.radius_mean,data.area_mean,kind="reg")
sns.jointplot(data.radius_mean,data.fractal_dimension_mean,kind="reg")
plt.show()

# %%
# Also we can look relationship between more than 2 distribution
sns.set(style = "white")
df = data.loc[:,["radius_mean","area_mean","fractal_dimension_se"]]
g = sns.PairGrid(df,diag_sharey = False,)
g.map_lower(sns.kdeplot,cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot,lw =3)
plt.show()

# %% [markdown]
# * Covariance
#     * Kovaryans iki değişkenin birlikte ne kadar değiştiklerinin ölçüsüdür.
#         * ![Time](covar.jpg)
#     * Eğer iki vektor identical ise covariance maximum olur.
#     * Eğer iki vektor arasında bir ilişki yoksa covariance sıfır olur
#     * Eğer iki vektor farklı yönlerde ise covariance negative olur.
#     * radius_mean and area_mean arasındaki covariance'a bakalım.
#     * Daha sonra radius_mean and fractal_dimension_se arasındaki covariance'a bakalım.

# %%
np.cov(data.radius_mean,data.area_mean)
print("Covariance between radius mean and area mean: ",data.radius_mean.cov(data.area_mean))
print("Covariance between radius mean and fractal dimension se: ",data.radius_mean.cov(data.fractal_dimension_se))
fig, axs = plt.subplots(1, 2)
axs[0].scatter(data.radius_mean, data.area_mean)
axs[1].scatter(data.fractal_dimension_se, data.radius_mean)
plt.show()
# Out:
# Covariance between radius mean and area mean:  1224.4834093464565
# Covariance between radius mean and fractal dimension se:  -0.00039762485764406277

# %% [markdown]
# <a id="14"></a>
# ## Pearson Correlation Coefficient (Pearson Korelasyon Katsayısı)
# * Pearson Correlation Coefficient: covariance'ı variable'ların standart deviation'ına bölüyoruz
# * Division of covariance by standart deviation of variables
# * radius mean and area mean arasındaki pearson correlation katsayısına bakalım
# * Pearson Correlation Coefficient +1 ve -1 değerleri arasında değişir.
#     * +1 = positive linear correlation
#     * -1 = negative linear correlation
#     *  0 = linear correlation yok
# * ![Time](pearson.jpg)

# %%
p1 = data.loc[:,["area_mean","radius_mean"]].corr(method= "pearson")
p2 = data.radius_mean.cov(data.area_mean)/(data.radius_mean.std()*data.area_mean.std())
print('Pearson correlation: ')
print(p1)
print('Pearson correlation: ',p2)
# Out:
# Pearson correlation:
#              area_mean  radius_mean
# area_mean     1.000000     0.987357
# radius_mean   0.987357     1.000000
# Pearson correlation:  0.9873571700566128

# %% [markdown]
# <a id="15"></a>
# ## Spearman Rank Coefficient (Spearman Rank Katsayısı)
# * Pearson korelasyonu, değişkenler arasındaki ilişki doğrusalsa ve değişkenler kabaca normalse iyi çalışır. Ancak aykırı değerler varsa sağlam değildir.
# * Spearman korelasyonunu hesaplamak için her bir değerin derecesini hesaplamamız gerekir.

# %%
ranked_data = data.rank()

# %%
ranked_data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        463.5        476.5           2.0           492.0      478.0
# 1        463.5        540.0         223.0           528.5      544.0
# 2        463.5        519.0         396.5           517.5      516.0
# 3        463.5        118.0         364.0           173.0      100.0
# 4        463.5        532.0          64.0           539.0      537.0
# ..         ...          ...           ...             ...        ...
# 564      463.5        552.0         453.0           550.0      553.0
# 565      463.5        526.0         554.0           524.0      529.0
# 566      463.5        446.0         549.0           442.0      447.0
# 567      463.5        543.0         558.0           547.0      532.0
# 568      179.0          4.0         503.0             2.0        4.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# rank anlamak icin ornek
data1 = {'name': ['ali', 'veli', 'hakan', 'ayse', 'fatma'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3],
        'coverage': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data1, index = ['ankara', 'istanbul', 'sinop', 'bolu', 'izmir'])
df
# Out:
#            name  year  reports  coverage
# ankara      ali  2012        4        25
# istanbul   veli  2012       24        94
# sinop     hakan  2013       31        57
# bolu       ayse  2014        2        62
# izmir     fatma  2014        3        70

# %%
df['default_rank'] = df['coverage'].rank()
df['acsending_rank'] = df['coverage'].rank(ascending=1)
df['max_rank'] = df['coverage'].rank(method='max')
#df['NA_bottom'] = df['coverage'].rank(na_option='bottom')
df['pct_rank'] = df['coverage'].rank(pct=True)
df
# Out:
#            name  year  reports  coverage  default_rank  acsending_rank  \
# ankara      ali  2012        4        25           1.0             1.0
# istanbul   veli  2012       24        94           5.0             5.0
# sinop     hakan  2013       31        57           2.0             2.0
# bolu       ayse  2014        2        62           3.0             3.0
# izmir     fatma  2014        3        70           4.0             4.0
#
#           max_rank  pct_rank
# ankara         1.0       0.2
# istanbul       5.0       1.0
# sinop          2.0       0.4
# bolu           3.0       0.6
# izmir          4.0       0.8

# %%
ranked_data = data.rank() 
spearman_corr = ranked_data.loc[:,["area_mean","radius_mean"]].corr(method= "pearson")
print("Spearman's correlation: ")
print(spearman_corr)
# Out:
# Spearman's correlation:
#              area_mean  radius_mean
# area_mean     1.000000     0.999602
# radius_mean   0.999602     1.000000

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
ranked_data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        463.5        476.5           2.0           492.0      478.0
# 1        463.5        540.0         223.0           528.5      544.0
# 2        463.5        519.0         396.5           517.5      516.0
# 3        463.5        118.0         364.0           173.0      100.0
# 4        463.5        532.0          64.0           539.0      537.0
# ..         ...          ...           ...             ...        ...
# 564      463.5        552.0         453.0           550.0      553.0
# 565      463.5        526.0         554.0           524.0      529.0
# 566      463.5        446.0         549.0           442.0      447.0
# 567      463.5        543.0         558.0           547.0      532.0
# 568      179.0          4.0         503.0             2.0        4.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# <a id="16"></a>
# ## Effect size
# * Bir efektin boyutunu tanımlar.
# * Cohen efekt boyutu, d(etki büyüklüğü)= 0,2 ise, bunun küçük etki büyüklüğü, d = 0,5 orta etki büyüklüğü, d = 0,8 büyük etki büyüklüğü olduğunu önermektedir.
# * malignant radius mean ile bening radius mean arasında bir etki olup olmadığını ölçelim.
# ![Time](efect.jpg)

# %%
data_bening = data[data["diagnosis"] == "B"]
data_malignant = data[data["diagnosis"] == "M"]
mean_diff = data_malignant.radius_mean.mean() - data_bening.radius_mean.mean()    # m1 - m2
var_bening = data_bening.radius_mean.var()
var_malignant = data_malignant.radius_mean.var()
cohens_d = (mean(data_malignant.radius_mean) - mean(data_bening.radius_mean)) / (sqrt((stdev(data_malignant.radius_mean) ** 2 + stdev(data_bening.radius_mean) ** 2) / 2))

print("Effect size: ",cohens_d)
# Out:
# Effect size:  2.0511414795444516

# %%
a = np.random.randint(1,7,60000)
print("sample space: ",np.unique(a))
plt.hist(a,bins=12)
plt.ylabel("Number of outcomes")
plt.xlabel("Possible outcomes")
plt.show()
# Out:
# sample space:  [1 2 3 4 5 6]

# %% [markdown]
# <a id="34"></a>
# ## Binomial Distributions
# * Binomial: 2 tane discrete sonucu olan bir trial(deneme).
# * En güzel örneği yazı tura atmak.
# * Bernoulli Trial:
#     * Success or failure diye 2 tane sonucu olan random deneyler
#     * n = number of trial
#     * p = probability of success
#     * r = number of success
#     * trials birbirinden bağımsız yani independent
#     * ![Time](bernoille.jpg)

# %%
# yazı tura
n = 2 # number of trials
p = 0.5 # probability of each trial
s = np.random.binomial(n, p,10000) # 10000 = number of test
weights = np.ones_like(s)/float(len(s))
plt.hist(s, weights=weights)
plt.xlabel("number of success") # grafigin soluna dogru basari azaliyor
plt.ylabel("probability")
plt.show()
# 0.25 prob 0 success (2 yazı)
# 0.5 prob 1 success  (yazı-tura)
# 0.25 prob 2 success (2 tura)
# (yazı-yazı)(yazı-tura)(tura-yazı)(tura-tura)

# %% [markdown]
# <a id="36"></a>
# ## Poisson Distributions
# * Binomial: number of successes out of n trials
# * Poisson: number of successes per unit of time
# * lambda = number of occurences / interval
# * interval zamana olabilir distance(mesafe) olabilir
# * Örneğin lambda = 10 olsun. Bir taşımacılık şirketi için bu değer her bir saatte ortalama 10 kamyon anlamına gelebilir.
# * ![Time](posss.jpg)

# %%
# örnegin her saatte ortalama 3 kamyon gorsellestirmesi
lamda = 10
s1 = np.random.poisson(lamda,100000)
weights1 = np.ones_like(s1)/float(len(s1))
plt.hist(s1, weights=weights1,bins = 100)
plt.xlabel("number of occurances") # grafigin soluna dogru basari azaliyor
plt.ylabel("probability")
# sekilde goruldugu gibi en yuksek olasilik saatte 10 kamyon ama saatte 20 kamyon bile olabilir
# Out:
# Text(0, 0.5, 'probability')

# %%
# parameters of normal distribution
mu, sigma = 110, 20  # mean and standard deviation
s = np.random.normal(mu, sigma, 100000)
print("mean: ", np.mean(s))
print("standart deviation: ", np.std(s))
# visualize with histogram
plt.figure(figsize = (10,7))
plt.hist(s, 100)
plt.ylabel("frequency")
plt.xlabel("IQ")
plt.title("Histogram of IQ")
plt.show()
# Out:
# mean:  109.93463965026446
# standart deviation:  20.055455956146034

# %% [markdown]
# * Histogramdan da anlaşılacağı gibi insanların çoğu, normal dağılımımızın ortalaması olan 110'a yakın bir yerde toplanmıştır.
# * Ancak bir önceki cümlede bahsettiğim "en" nedir? İnsanların yüzde kaçının IQ puanının 80 ile 140 arasında olması gerektiğini bilmek istersem ne olur?
# * Bu sorunun cevabı için z-skorunu kullanacağız.
#     * z = (x - mean)/std
#     * z1 = (80-110)/20 = -1.5
#     * z2 = (140-110)/20 = 1.5
#     * Ortalama ile 80 arasındaki mesafe 1.5std ve ortalama ile 140 arasındaki mesafe 1.5std'dir.
#     * z tablosuna bakarsanız, 1.5std'nin 0.4332'ye karşılık geldiğini göreceksiniz.
#     * ![Time](z_score.jpg)
#     * Lets calculate it with 2 because 1 from 80 to mean and other from mean to 140
#     * 0.4332 * 2 = 0.8664
#     * 86.64 % of people has an IQ between 80 and 140.
#     * ![Time](hist_iq.jpg)

# %%
df = pd.read_csv('house_price.csv')

# %%
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
import pandas_profiling 
profile = df.profile_report(title='Pandas Profiling Report')
profile.to_file(output_file="Data_Profiling_v1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
